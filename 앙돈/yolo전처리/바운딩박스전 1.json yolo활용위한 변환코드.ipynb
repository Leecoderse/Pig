# %% [markdown]
# ## 환경설정

# %%
# 구글 드라이브 마운트
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 불러올 파일 위치 지정
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## 최초 설치

# %%
# !git clone https://github.com/ssaru/convert2Yolo.git
# Out:
# Cloning into 'convert2Yolo'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 215 (delta 38), reused 35 (delta 35), pack-reused 172
# Receiving objects: 100% (215/215), 994.67 KiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# %cd ./convert2Yolo
# Out:
# /content/drive/MyDrive/convert2Yolo

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## 구동 코드

# %%
# !python ./convert2Yolo/example.py --datasets COCO --img_path ./앙돈/data/Training/image/bbox/ --label ./앙돈/data/Train/json/annotation.json --convert_output_path ./앙돈/data/변환/ --img_type ".jpg"  --manifest_path ./앙돈/data/ --cls_list_file ./앙돈/data/names.txt
# Out:
# COCO Parsing:  |████████████████████████████████████████| 100.0% (71151/71151)  Complete
#
#
# YOLO Generating:|████████████████████████████████████████| 100.0% (2700/2700)  Complete
#
#
# YOLO Saving:   |████████████████████████████████████████| 100.0% (2700/2700)  Complete
